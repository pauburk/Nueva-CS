# %% [markdown]
# Link to intro to dataset processing:
#
# <https://nbviewer.jupyter.org/github/jennselby/MachineLearningCourseNotes/blob/master/assets/ipynb/IntroductiontoDatasetProcessing.ipyn>
#
# Link to dataset:
#
# <https://www.kaggle.com/datacrux/barack-obama-twitterdata-from-20122019>

# %% [markdown]
# # Setup

# %%
# imports

import sklearn
import pandas
from sklearn.preprocessing import StandardScaler # for standardization
from sklearn.feature_extraction.text import CountVectorizer # for counting words

# %%
# import data into dataframe

df = pandas.read_csv('./tweets-BarackObama.csv')
print(len(df.index), "rows")
df.head()
# Out:
# 6851 rows
#                Date                         Username  \
# 0  2019/04/10_17:08  https://twitter.com/BarackObama
# 1  2019/04/06_06:16  https://twitter.com/BarackObama
# 2  2019/04/05_09:25  https://twitter.com/BarackObama
# 3  2019/04/04_12:23  https://twitter.com/BarackObama
# 4  2019/04/03_12:07  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# 3  https://twitter.com/BarackObama/status/1113884...     15396   78627
# 4  https://twitter.com/BarackObama/status/1113518...      8991   98094
#
#   TweetImageUrl  Image
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN

# %% [markdown]
# # Start cleaning stuff up

# %%
# Seperate date column into date and time
# We could go even further and seperate date into year, month, and day and time into hours and minutes, but this is good enough for now

dates = []
times = []

for index, row, in df.iterrows():
    
    s = row["Date"].split("_")
    
    date = s[0]
    time = s[1]
    
    dates.append(date)
    times.append(time)
    
# I could also do something like this

# df_temp = df['Date'].str.split('_', expand=True)
# df = pandas.concat([df, df_temp], axis=1, sort=False)

# %%
# Delete original "Date" column, add in new "Date" and "Time" columns

df = df.drop("Date", axis=1)
df.insert(0, "Date", dates) # insert column at beginning
df.insert(1, "Time", times) # insert column at beginning
df.head()
# Out:
#          Date   Time                         Username  \
# 0  2019/04/10  17:08  https://twitter.com/BarackObama
# 1  2019/04/06  06:16  https://twitter.com/BarackObama
# 2  2019/04/05  09:25  https://twitter.com/BarackObama
# 3  2019/04/04  12:23  https://twitter.com/BarackObama
# 4  2019/04/03  12:07  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# 3  https://twitter.com/BarackObama/status/1113884...     15396   78627
# 4  https://twitter.com/BarackObama/status/1113518...      8991   98094
#
#   TweetImageUrl  Image
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN

# %%
# Remove colons from the time column (we could also do this to the date column but I'm just not doing that here)
# There is probably a way to do this with regex and something like df.replace("\d\d(:)\d\d", "") but I'm not sure how

new_times = []

for index, row, in df.iterrows():
    
    time = row["Time"]
    time = time.replace(":", "")
    
    new_times.append(time)
    
df = df.drop("Time", axis=1)
df.insert(1, "Time", new_times)
df.head()
# Out:
#          Date  Time                         Username  \
# 0  2019/04/10  1708  https://twitter.com/BarackObama
# 1  2019/04/06  0616  https://twitter.com/BarackObama
# 2  2019/04/05  0925  https://twitter.com/BarackObama
# 3  2019/04/04  1223  https://twitter.com/BarackObama
# 4  2019/04/03  1207  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# 3  https://twitter.com/BarackObama/status/1113884...     15396   78627
# 4  https://twitter.com/BarackObama/status/1113518...      8991   98094
#
#   TweetImageUrl  Image
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN

# %%
# Delete "Image" column because there are no image thumbnails (all the values are NaN)

df = df.drop("Image", axis=1)
df.head()
# Out:
#          Date  Time                         Username  \
# 0  2019/04/10  1708  https://twitter.com/BarackObama
# 1  2019/04/06  0616  https://twitter.com/BarackObama
# 2  2019/04/05  0925  https://twitter.com/BarackObama
# 3  2019/04/04  1223  https://twitter.com/BarackObama
# 4  2019/04/03  1207  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# 3  https://twitter.com/BarackObama/status/1113884...     15396   78627
# 4  https://twitter.com/BarackObama/status/1113518...      8991   98094
#
#   TweetImageUrl
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# # Dealing with the image urls

# %%
# We could just delete this column if we have no use for any images in any tweets

df_1 = df.drop("TweetImageUrl", axis=1)
df_1.head()
# Out:
#          Date  Time                         Username  \
# 0  2019/04/10  1708  https://twitter.com/BarackObama
# 1  2019/04/06  0616  https://twitter.com/BarackObama
# 2  2019/04/05  0925  https://twitter.com/BarackObama
# 3  2019/04/04  1223  https://twitter.com/BarackObama
# 4  2019/04/03  1207  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# 3  https://twitter.com/BarackObama/status/1113884...     15396   78627
# 4  https://twitter.com/BarackObama/status/1113518...      8991   98094

# %%
# Or if we are running analysis on the tweets with images (and we can't use tweets without images), we can delete every row without an image url

df_2 = df.dropna()
df_2.head()
# Out:
#           Date  Time                         Username  \
# 5   2019/04/02  0608  https://twitter.com/BarackObama
# 6   2019/03/26  1133  https://twitter.com/BarackObama
# 7   2019/03/21  0843  https://twitter.com/BarackObama
# 10  2019/03/17  0656  https://twitter.com/BarackObama
# 15  2019/03/08  0803  https://twitter.com/BarackObama
#
#                                            Tweet-text  \
# 5   Valerie is one of my oldest friends and adviso...
# 6   Last night I had the chance to meet with first...
# 7   Just in the nick of time: My brackets have nev...
# 10  In 2011 I visited the tiny town of Moneygall a...
# 15  The Crew Dragon’s been on quite a ride since I...
#
#                                            Tweet Link  Retweets   Likes  \
# 5   https://twitter.com/BarackObama/status/1113065...      6839   66187
# 6   https://twitter.com/BarackObama/status/1110610...     14325  117989
# 7   https://twitter.com/BarackObama/status/1108756...      8457   59574
# 10  https://twitter.com/BarackObama/status/1107279...     23726  244904
# 15  https://twitter.com/BarackObama/status/1104049...     10923  130875
#
#                                       TweetImageUrl
# 5   https://pbs.twimg.com/media/D3JnZdBVYAEVq8U.jpg
# 6   https://pbs.twimg.com/media/D2musJoWsAIFVwg.jpg
# 7   https://pbs.twimg.com/media/D2MXyrbWsAAdVSz.jpg
# 10  https://pbs.twimg.com/media/D13Y3rOWsAA42ma.jpg
# 15  https://pbs.twimg.com/media/D1JfmpgXcAUJo_R.jpg

# %% [markdown]
# # Bag of words the tweets (for final project)

# %%
bow = []

for index, row in df_2.iterrows():
    
    tweet = row["Tweet-text"]
    
    words_list = tweet.split()
    words_dict = {}
    
    for w in words_list:
        if w not in words_dict:
            words_dict[w] = 1
        else:
            words_dict[w] += 1

    bow.append(words_dict)
    
df_2["bow"] = bow
df_2.head()
# Out:
# <ipython-input-22-3725837bd40c>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2["bow"] = bow
#           Date  Time                         Username  \
# 5   2019/04/02  0608  https://twitter.com/BarackObama
# 6   2019/03/26  1133  https://twitter.com/BarackObama
# 7   2019/03/21  0843  https://twitter.com/BarackObama
# 10  2019/03/17  0656  https://twitter.com/BarackObama
# 15  2019/03/08  0803  https://twitter.com/BarackObama
#
#                                            Tweet-text  \
# 5   Valerie is one of my oldest friends and adviso...
# 6   Last night I had the chance to meet with first...
# 7   Just in the nick of time: My brackets have nev...
# 10  In 2011 I visited the tiny town of Moneygall a...
# 15  The Crew Dragon’s been on quite a ride since I...
#
#                                            Tweet Link  Retweets   Likes  \
# 5   https://twitter.com/BarackObama/status/1113065...      6839   66187
# 6   https://twitter.com/BarackObama/status/1110610...     14325  117989
# 7   https://twitter.com/BarackObama/status/1108756...      8457   59574
# 10  https://twitter.com/BarackObama/status/1107279...     23726  244904
# 15  https://twitter.com/BarackObama/status/1104049...     10923  130875
#
#                                       TweetImageUrl  \
# 5   https://pbs.twimg.com/media/D3JnZdBVYAEVq8U.jpg
# 6   https://pbs.twimg.com/media/D2musJoWsAIFVwg.jpg
# 7   https://pbs.twimg.com/media/D2MXyrbWsAAdVSz.jpg
# 10  https://pbs.twimg.com/media/D13Y3rOWsAA42ma.jpg
# 15  https://pbs.twimg.com/media/D1JfmpgXcAUJo_R.jpg
#
#                                                   bow
# 5   {'Valerie': 1, 'is': 1, 'one': 1, 'of': 2, 'my...
# 6   {'Last': 1, 'night': 1, 'I': 1, 'had': 1, 'the...
# 7   {'Just': 1, 'in': 1, 'the': 1, 'nick': 1, 'of'...
# 10  {'In': 1, '2011': 1, 'I': 1, 'visited': 1, 'th...
# 15  {'The': 1, 'Crew': 1, 'Dragon’s': 1, 'been': 1...

# %% [markdown]
# # Standardization

# %%
# Now if we want to standardize the retweets and likes values...

scaler = StandardScaler()
df_s = pandas.DataFrame(data=scaler.fit_transform(df[["Retweets", "Likes"]]), columns=["Retweets", "Likes"])
df_s.head()
# Out:
#    Retweets     Likes
# 0  0.524620  1.408344
# 1  0.032596  0.193133
# 2  0.742825  1.053901
# 3  0.350968  0.564358
# 4  0.150853  0.734605

# %%
# We can add these standardized values back into the original dataframe and rename the original columns to keep things organized

df = df.rename(columns={"Retweets": "Retweets (og)", "Likes": "Likes (og)"})

df.insert(7, "Retweets (s)", df_s[["Retweets"]])
df.insert(8, "Likes (s)", df_s[["Likes"]])

df.head()
# Out:
#          Date  Time                         Username  \
# 0  2019/04/10  1708  https://twitter.com/BarackObama
# 1  2019/04/06  0616  https://twitter.com/BarackObama
# 2  2019/04/05  0925  https://twitter.com/BarackObama
# 3  2019/04/04  1223  https://twitter.com/BarackObama
# 4  2019/04/03  1207  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets (og)  \
# 0  https://twitter.com/BarackObama/status/1116130...          20954
# 1  https://twitter.com/BarackObama/status/1114517...           5206
# 2  https://twitter.com/BarackObama/status/1114202...          27938
# 3  https://twitter.com/BarackObama/status/1113884...          15396
# 4  https://twitter.com/BarackObama/status/1113518...           8991
#
#    Likes (og)  Retweets (s)  Likes (s) TweetImageUrl
# 0      175133      0.524620   1.408344           NaN
# 1       36179      0.032596   0.193133           NaN
# 2      134604      0.742825   1.053901           NaN
# 3       78627      0.350968   0.564358           NaN
# 4       98094      0.150853   0.734605           NaN

# %%
# Now that we're done cleaning things up, lets find all of Obama's tweets which mention the nba!

condition = df['Tweet-text'].str.contains('NBA')
filtered_data = df[condition]
filtered_data.head()
# Out:
#             Date  Time                         Username  \
# 0     2019/04/10  1708  https://twitter.com/BarackObama
# 24    2019/02/16  1240  https://twitter.com/BarackObama
# 5709  2013/06/20  1611  https://twitter.com/BarackObama
# 5747  2013/06/14  1332  https://twitter.com/BarackObama
# 5753  2013/06/13  1712  https://twitter.com/BarackObama
#
#                                              Tweet-text  \
# 0     From a big NBA fan congrats to future Hall of ...
# 24    I’ve always loved basketball because it’s abou...
# 5709  Nothing better than a Game 7 for all the marbl...
# 5747  If you're from Indiana you'd better have a goo...
# 5753  Don't miss @selcharrodeoro's encore performanc...
#
#                                              Tweet Link  Retweets (og)  \
# 0     https://twitter.com/BarackObama/status/1116130...          20954
# 24    https://twitter.com/BarackObama/status/1096871...          23270
# 5709  https://twitter.com/BarackObama/status/3478543...           5565
# 5747  https://twitter.com/BarackObama/status/3456398...            622
# 5753  https://twitter.com/BarackObama/status/3453328...           2543
#
#       Likes (og)  Retweets (s)  Likes (s) TweetImageUrl
# 0         175133      0.524620   1.408344           NaN
# 24        160902      0.596980   1.283888           NaN
# 5709        1913      0.043812  -0.106538           NaN
# 5747         372     -0.110625  -0.120015           NaN
# 5753        1757     -0.050606  -0.107902           NaN

# %%
# We can also find his most commonly used word

# Create a string made up of every single tweet
all_tweets = ""
for index, row, in df.iterrows():  
    all_tweets = all_tweets + " " + row["Tweet-text"]
        
count_vect = CountVectorizer() 
counts = count_vect.fit_transform([all_tweets])
# word_counts_df = pd.DataFrame(data=counts.todense())
word_nums = count_vect.vocabulary_
print(max(word_nums, key=word_nums.get))
# Out:
# zyyrca

# %% [markdown]
# Hmmm, that doesn't seem to be working quite properly... (although when I print out word_nums and eyeball things "zyyrca" does seem to have the largest value)

# %%
for label, content in df_new.items():
    content = content.tolist()
    if content[0] == "Positive" or content[0] == "Negative":
        print(label)
